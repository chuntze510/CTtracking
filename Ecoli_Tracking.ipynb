# %%
import numpy as np
import cv2
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 10))
mpl.rc('image', cmap='gray')

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims
import trackpy as tp

# %%
cellimg=cv2.imread('C:/Users/user/Downloads/trackpy-examples-master/sample_data/bulk_water/bulk_water_000.png',0)

# %%
#cell = pims.open('C:/Users/user/Downloads/trackpy-examples-master/sample_data/bulk_water/*.png',as_grey=True)
#可以開啟多個檔案轉成list

# %%
plt.figure(figsize=(10,10))
plt.imshow(cellimg)

# %%
cellimg.shape
# Out:
# (424, 640)

# %%
count = tp.locate(cellimg, 13, invert=True) #必須是奇數

# %%
mpl.rc('figure',  figsize=(10, 10))
mpl.rc('image', cmap='gray')
plt.figure()  # make a new figure
tp.annotate(count, cellimg)

# %%
mpl.rc('figure',  figsize=(10, 5))
tp.subpx_bias(count)
plt.show()

# %%
mpl.rc('figure',  figsize=(10, 5))   #mask太小直方圖會下降讓分不不平均
tp.subpx_bias(tp.locate(cellimg, 5, invert=True));
plt.show()
